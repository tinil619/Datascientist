# %%
print("Land prediction project")
# Out:
# Land prediction project

# %%
import pandas as pd
import numpy as np

#file = pd.read_excel(r'C:\Users\tinil\OneDrive\Desktop\Tinil\Pantech course\Data Analytics\Land_price.xlsx')

from google.colab import files
uploaded = files.upload_file(r'C:\Users\tinil\OneDrive\Desktop\Tinil\Pantech course\Data Analytics\Land_price.xlsx')
# Out:
#      <input type="file" id="files-69d2e6d1-8bba-4f2c-9b72-a67245e0bdb3" name="files[]"  disabled
#         style="border:none" />
#      <output id="result-69d2e6d1-8bba-4f2c-9b72-a67245e0bdb3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# /**
# ...

# %%
dataset = pd.read_excel(r'C:\Users\tinil\OneDrive\Desktop\Tinil\Pantech course\Data Analytics\Land_price.xlsx')
dataseuwithNan = (dataset)
dataset
# Out:
#     Land      Price
# 0   1000     2245.0
# 1   2000     4575.0
# 2   3000     6874.0
# 3   4000     8878.0
# 4   5000        NaN
# 5   6000    12457.0
# 6   7000    14785.0
# 7   8000    16785.0
# 8   9000    20589.0
# 9  10000  2078900.0

# %%
print(dataset.shape)
# Out:
# (10, 2)

# %%
print(dataset.describe())
# Out:
#                Land         Price
# count     10.000000  9.000000e+00
# mean    5500.000000  2.406764e+05
# std     3027.650354  6.893593e+05
# min     1000.000000  2.245000e+03
# 25%     3250.000000  6.874000e+03
# 50%     5500.000000  1.245700e+04
# 75%     7750.000000  1.678500e+04
# max    10000.000000  2.078900e+06

# %%
dataset.isnull()
# Out:
#     Land  Price
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False   True
# 5  False  False
# 6  False  False
# 7  False  False
# 8  False  False
# 9  False  False

# %%
dataset.isna().any()
# Out:
# Land     False
# Price     True
# dtype: bool

# %%
fillnadata = dataset.Price.fillna(dataset.Price.mean())
fillnadata.dtype
# Out:
# dtype('float64')

# %%
fillnadata.isna().any()
# Out:
# False

# %%
fillnadata = dataset.Price.fillna(dataset.Price.median())
fillnadata
# Out:
# 0       2245.0
# 1       4575.0
# 2       6874.0
# 3       8878.0
# 4      12457.0
# 5      12457.0
# 6      14785.0
# 7      16785.0
# 8      20589.0
# 9    2078900.0
# Name: Price, dtype: float64
